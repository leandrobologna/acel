# %%
from urllib.request import urlopen

# %%
url = 'https://data.boston.gov/api/3/action/datastore_search?resource_id=4582bec6-2b4f-4f9e-bc55-cbaa73117f4c'

# %%
fileobj = urlopen(url)

# %%
print(fileobj.read())
# Out:
# b'{"help": "https://data.boston.gov/api/3/action/help_show?name=datastore_search", "success": true, "result": {"include_total": true, "resource_id": "4582bec6-2b4f-4f9e-bc55-cbaa73117f4c", "fields": [{"type": "int", "id": "_id"}, {"type": "text", "id": "businessname"}, {"type": "text", "id": "dbaname"}, {"type": "text", "id": "legalowner"}, {"type": "text", "id": "namelast"}, {"type": "text", "id": "namefirst"}, {"type": "text", "id": "licenseno"}, {"type": "text", "id": "issdttm"}, {"type": "text", "id": "expdttm"}, {"type": "text", "id": "licstatus"}, {"type": "text", "id": "licensecat"}, {"type": "text", "id": "descript"}, {"type": "text", "id": "result"}, {"type": "text", "id": "resultdttm"}, {"type": "text", "id": "violation"}, {"type": "text", "id": "viollevel"}, {"type": "text", "id": "violdesc"}, {"type": "text", "id": "violdttm"}, {"type": "text", "id": "violstatus"}, {"type": "text", "id": "statusdate"}, {"type": "text", "id": "comments"}, {"type": "text", "id": "address"}, {"type": "text", "id": "city"}, {"type": "text", "id": "state"}, {"type": "text", "id": "zip"}, {"type": "text", "id": "property_id"}, {"type": "text", "id": "location"}], "records_format": "objects", "records": [{"licenseno": "87059", "issdttm": "2013-04-05 12:47:23", "violdttm": "2013-02-15 12:19:42", "violation": "15-4-202.16", "viollevel": "*", "address": "635   Hyde Park AVE", "violstatus": "Fail", "result": "HE_Fail", "licensecat": "FS", "property_id": "77476", "city": "Roslindale", "zip": "02131", "licstatus": "Active", "comments": "Provide glass storage rack.", "state": "MA", "location": "(42.278590000, -71.119440000)", "namelast": "Marte", "businessname": "100 Percent Delicia Food", "statusdate": null, "violdesc": "Non-Food Contact Surfaces", "expdttm": "2019-12-31 23:59:00", "namefirst": "Civelis", "descript": "Eating & Drinking", "resultdttm": "2013-02-15 12:19:42", "legalowner": "BRENNAN PATRICK E", "dbaname": null, "_id": 1}, {"licenseno": "87059", "issdttm": "2013-04-05 12:47:23", "violdttm": "2013-02-15 12:19:42", "violation": "16-4-501.11/.15", "viollevel": "*", "address": "635   Hyde Park AVE", "violstatus": "Fail", "result": "HE_Fail", "licensecat": "FS", "property_id": "77476", "city": "Roslindale", "zip": "02131", "licstatus": "Active", "comments": "Provide dish rack over 3 bay sink to replace missing drainboards at each end of  3 bay sink.", "state": "MA", "location": "(42.278590000, -71.119440000)", "namelast": "Marte", "businessname": "100 Percent Delicia Food", "statusdate": null, "violdesc": "Dishwashng Facilities", "expdttm": "2019-12-31 23:59:00", "namefirst": "Civelis", "descript": "Eating & Drinking", "resultdttm": "2013-02-15 12:19:42", "legalowner": "BRENNAN PATRICK E", "dbaname": null, "_id": 2}, {"licenseno": "87059", "issdttm": "2013-04-05 12:47:23", "violdttm": "2013-02-15 12:19:42", "violation": "16-4-501.11/.15", "viollevel": "*", "address": "635   Hyde Park AVE", "violstatus": "Fail", "result": "HE_Fail", "licensecat": "FS", "property_id": "77476", "city": "Roslindale", "zip": "02131", "licstatus": "Active", "comments": "Provide dish washer at ware washing area.", "state": "MA", "location": "(42.278590000, -71.119440000)", "namelast": "Marte", "businessname": "100 Percent Delicia Food", "statusdate": null, "violdesc": "Dishwashng Facilities", "expdttm": "2019-12-31 23:59:00", "namefirst": "Civelis", "descript": "Eating & Drinking", "resultdttm": "2013-02-15 12:19:42", "legalowner": "BRENNAN PATRICK E", "dbaname": null, "_id": 3}, {"licenseno": "87059", "issdttm": "2013-04-05 12:47:23", "violdttm": "2013-02-15 12:19:42", "violation": "29-5-201/02.11", "viollevel": "*", "address": "635   Hyde Park AVE", "violstatus": "Fail", "result": "HE_Fail", "licensecat": "FS", "property_id": "77476", "city": "Roslindale", "zip": "02131", "licstatus": "Active", "comments": "Provide mop sink at basement.", "state": "MA", "location": "(42.278590000, -71.119440000)", "namelast": "Marte", "businessname": "100 Percent Delicia Foo ...

# %%
df_json
# Out:
# b''
